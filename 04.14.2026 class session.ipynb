# %%
import numpy as np

# %% [markdown]
# This code adds **one plus one**

# %%
name="Luissa"
age=31
favourite_number=0

# %%
name
# Out:
# 'Luissa'

# %%
age
# Out:
# 31

# %%
favourite_number
# Out:
# 0

# %%
name, age, favourite_number
# Out:
# ('Luissa', 31, 0)

# %%
age += 10

# %%
age
# Out:
# 41

# %%
def f_to_c(f_deg):
    return(f_deg-32)*5/9 #Conversion formula

# %%
f_to_c(32)
# Out:
# 0.0

# %%
def luissa_function(proportion):
    """
    This function converts proportions into percents
    User needs the proportion parameter as a float variable
    """
    return proportion*100

# %%
luissa_function(0.0045848)
# Out:
# 0.45848

# %%
help(luissa_function)
# Out:
# Help on function luissa_function in module __main__:
#
# luissa_function(proportion)
#     This function converts proportions into percents
#     User needs the proportion parameter as a float variable
